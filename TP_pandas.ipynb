# %% [markdown]
# sabritarik001@gmail.com

# %% [markdown]
# # 1

# %%
import pandas as pd

data = pd.read_csv('employes.csv')

# %% [markdown]
# # 2

# %%
data.head(5)
# Out:
#    EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL      PHONE_NUMBER  \
# 0          198   Donald        OConnell      DOCONNEL   650.507.9833
# 1          199   Douglas       Grant         DGRANT     650.507.9844
# 2          200   Jennifer      Whalen        JWHALEN    515.123.4444
# 3          201   Michael       Hartstein     MHARTSTE
# 4          202   Pat           Fay           PFAY       603.123.6666
#
#     HIRE_DATE   JOB_ID       SALARY   COMMISSION_PCT   MANAGER_ID  \
# 0   21-Jun-07   SH_CLERK       2600                           124
# 1   13-Jan-08   SH_CLERK       2600                           124
# 2   17-Sep-03   AD_ASST        4400                           101
# 3   17-Feb-04   MK_MAN        13000                           100
# 4   17-Aug-05   MK_REP         6000                           201
#
#     DEPARTMENT_ID
# 0              50
# 1              50
# 2              10
# 3              20
# 4              20

# %% [markdown]
# # 3

# %%
data_types = data.dtypes
print(data_types)
# Out:
# EMPLOYEE_ID         int64
#  FIRST_NAME        object
#  LAST_NAME         object
#  EMAIL             object
#  PHONE_NUMBER      object
#  HIRE_DATE         object
#  JOB_ID            object
#  SALARY             int64
#  COMMISSION_PCT    object
#  MANAGER_ID         int64
#  DEPARTMENT_ID      int64
# dtype: object

# %% [markdown]
# # 4

# %%
len(data)
# Out:
# 50

# %%
len(data.columns)
# Out:
# 11

# %% [markdown]
# # 5

# %%
data.columns = data.columns.str.strip()
data1 = data[['FIRST_NAME', 'LAST_NAME']]
print(data1)
# Out:
#       FIRST_NAME     LAST_NAME
# 0    Donald        OConnell
# 1    Douglas       Grant
# 2    Jennifer      Whalen
# 3    Michael       Hartstein
# 4    Pat           Fay
# 5    Susan         Mavris
# 6    Hermann       Baer
# 7    Shelley       Higgins
# 8    William       Gietz
# 9    Steven        King
# 10   Neena         Kochhar
# 11   Lex           De Haan
# 12   Alexander     Hunold
# 13   Bruce         Ernst
# 14   David         Austin
# 15   Valli         Pataballa
# 16   Diana         Lorentz
# 17   Nancy         Greenberg
# 18   Daniel        Faviet
# 19   John          Chen
# 20   Ismael        Sciarra
# 21   Jose Manuel   Urman
# 22   Luis          Popp
# 23   Den           Raphaely
# 24   Alexander     Khoo
# 25   Shelli        Baida
# 26   Sigal         Tobias
# 27   Guy           Himuro
# 28   Karen         Colmenares
# 29   Matthew       Weiss
# 30   Adam          Fripp
# 31   Payam         Kaufling
# 32   Shanta        Vollman
# 33   Kevin         Mourgos
# 34   Julia         Nayer
# 35   Irene         Mikkilineni
# 36   James         Landry
# 37   Steven        Markle
# 38   Laura         Bissot
# 39   Mozhe         Atkinson
# 40   James         Marlow
# 41   TJ            Olson
# 42   Jason         Mallin
# 43   Michael       Rogers
# 44   Ki            Gee
# 45   Hazel         Philtanker
# 46   Renske        Ladwig
# 47   Stephen       Stiles
# 48   John          Seo
# 49   Joshua        Patel

# %% [markdown]
# # 6

# %%
data1.iloc[7:14]
# Out:
#       FIRST_NAME     LAST_NAME
# 7    Shelley       Higgins
# 8    William       Gietz
# 9    Steven        King
# 10   Neena         Kochhar
# 11   Lex           De Haan
# 12   Alexander     Hunold
# 13   Bruce         Ernst

# %% [markdown]
# # 7

# %%
data['FIRST_NAME'] + ' ' + data['LAST_NAME']
# Out:
# 0      Donald       OConnell
# 1      Douglas      Grant
# 2      Jennifer     Whalen
# 3      Michael      Hartstein
# 4      Pat          Fay
# 5      Susan        Mavris
# 6      Hermann      Baer
# 7      Shelley      Higgins
# 8      William      Gietz
# 9      Steven       King
# 10     Neena        Kochhar
# 11     Lex          De Haan
# 12     Alexander    Hunold
# 13     Bruce        Ernst
# 14     David        Austin
# 15     Valli        Pataballa
# 16     Diana        Lorentz
# 17     Nancy        Greenberg
# 18     Daniel       Faviet
# 19     John         Chen
# 20     Ismael       Sciarra
# 21     Jose Manuel  Urman
# 22     Luis         Popp
# 23     Den          Raphaely
# 24     Alexander    Khoo
# 25     Shelli       Baida
# 26     Sigal        Tobias
# 27     Guy          Himuro
# 28     Karen        Colmenares
# 29     Matthew      Weiss
# 30     Adam         Fripp
# 31     Payam        Kaufling
# 32     Shanta       Vollman
# 33     Kevin        Mourgos
# 34     Julia        Nayer
# 35     Irene        Mikkilineni
# 36     James        Landry
# 37     Steven       Markle
# 38     Laura        Bissot
# 39     Mozhe        Atkinson
# 40     James        Marlow
# 41     TJ           Olson
# 42     Jason        Mallin
# 43     Michael      Rogers
# 44     Ki           Gee
# 45     Hazel        Philtanker
# 46     Renske       Ladwig
# 47     Stephen      Stiles
# 48     John         Seo
# 49     Joshua       Patel
# dtype: object

# %% [markdown]
# # 8

# %%
data['ANNUAL_SALARY'] = data['SALARY'] * 12
data['ANNUAL_SALARY']
# Out:
# 0      31200
# 1      31200
# 2      52800
# 3     156000
# 4      72000
# 5      78000
# 6     120000
# 7     144096
# 8      99600
# 9     288000
# 10    204000
# 11    204000
# 12    108000
# 13     72000
# 14     57600
# 15     57600
# 16     50400
# 17    144096
# 18    108000
# 19     98400
# 20     92400
# 21     93600
# 22     82800
# 23    132000
# 24     37200
# 25     34800
# 26     33600
# 27     31200
# 28     30000
# 29     96000
# 30     98400
# 31     94800
# 32     78000
# 33     69600
# 34     38400
# 35     32400
# 36     28800
# 37     26400
# 38     39600
# 39     33600
# 40     30000
# 41     25200
# 42     39600
# 43     34800
# 44     28800
# 45     26400
# 46     43200
# 47     38400
# 48     32400
# 49     30000
# Name: ANNUAL_SALARY, dtype: int64

# %% [markdown]
# # 9

# %%
missing_values = data.isnull().sum()
print(missing_values)
print('\n')
missing_values = missing_values[missing_values > 0]
print(missing_values)
# Out:
# EMPLOYEE_ID          0
# FIRST_NAME           0
# LAST_NAME            0
# EMAIL                0
# PHONE_NUMBER         0
# HIRE_DATE            0
# JOB_ID               0
# SALARY               0
# COMMISSION_PCT       0
# MANAGER_ID           0
# DEPARTMENT_ID        0
# ANNUAL_SALARY        0
# HIRE_YEAR            0
# NEW_SALARY           0
# NEW_ANNUAL_SALARY    0
# YEARS_OF_SERVICE     0
# dtype: int64
#
#
# Series([], dtype: int64)

# %% [markdown]
# # 10

# %%
data['ANNUAL_SALARY'].mean()
# Out:
# 74187.84

# %% [markdown]
# # 11

# %%
data[data['ANNUAL_SALARY'] > data['ANNUAL_SALARY'].mean()]
# Out:
#     EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 3           201   Michael       Hartstein     MHARTSTE
# 5           203   Susan         Mavris        SMAVRIS    515.123.7777
# 6           204   Hermann       Baer          HBAER      515.123.8888
# 7           205   Shelley       Higgins       SHIGGINS
# 8           206   William       Gietz         WGIETZ     515.123.8181
# 9           100   Steven        King          SKING      515.123.4567
# 10          101   Neena         Kochhar       NKOCHHAR   515.123.4568
# 11          102   Lex           De Haan       LDEHAAN    515.123.4569
# 12          103   Alexander     Hunold        AHUNOLD    590.423.4567
# 17          108   Nancy         Greenberg     NGREENBE   515.124.4569
# 18          109   Daniel        Faviet        DFAVIET    515.124.4169
# 19          110   John          Chen          JCHEN      515.124.4269
# 20          111   Ismael        Sciarra       ISCIARRA   515.124.4369
# 21          112   Jose Manuel   Urman         JMURMAN    515.124.4469
# 22          113   Luis          Popp          LPOPP
# 23          114   Den           Raphaely      DRAPHEAL   515.127.4561
# 29          120   Matthew       Weiss         MWEISS     650.123.1234
# 30          121   Adam          Fripp         AFRIPP     650.123.2234
# 31          122   Payam         Kaufling      PKAUFLIN   650.123.3234
# 32          123   Shanta        Vollman       SVOLLMAN
#
#      HIRE_DATE       JOB_ID  SALARY   COMMISSION_PCT  MANAGER_ID  \
# 3    17-Feb-04   MK_MAN       13000                          100
# 5    7-Jun-02    HR_REP        6500                          101
# 6    7-Jun-02    PR_REP       10000                          101
# 7    7-Jun-02    AC_MGR       12008                          101
# 8    7-Jun-02    AC_ACCOUNT    8300                          205
# 9    17-Jun-03   AD_PRES      24000                          100
# 10   21-Sep-05   AD_VP        17000                          100
# 11   13-Jan-01   AD_VP        17000                          100
# 12   3-Jan-06    IT_PROG       9000                          102
# 17   17-Aug-02   FI_MGR       12008                          101
# 18   16-Aug-02   FI_ACCOUNT    9000                          108
# 19   28-Sep-05   FI_ACCOUNT    8200                          108
# 20   30-Sep-05   FI_ACCOUNT    7700                          108
# 21   7-Mar-06    FI_ACCOUNT    7800                          108
# 22   7-Dec-07    FI_ACCOUNT    6900                          108
# 23   7-Dec-02    PU_MAN       11000                          100
# 29   18-Jul-04   ST_MAN        8000                          100
# 30   10-Apr-05   ST_MAN        8200                          100
# 31   1-May-03    ST_MAN        7900                          100
# 32   10-Oct-05   ST_MAN        6500                          100
#
#     DEPARTMENT_ID  ANNUAL_SALARY
# 3              20         156000
# 5              40          78000
# 6              70         120000
# 7             110         144096
# 8             110          99600
# 9              90         288000
# 10             90         204000
# 11             90         204000
# 12             60         108000
# 17            100         144096
# 18            100         108000
# 19            100          98400
# 20            100          92400
# 21            100          93600
# 22            100          82800
# 23             30         132000
# 29             50          96000
# 30             50          98400
# 31             50          94800
# 32             50          78000

# %% [markdown]
# # 12

# %%
data.sort_values('SALARY')
# Out:
#     EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 41          132   TJ            Olson         TJOLSON    650.124.8234
# 45          136   Hazel         Philtanker    HPHILTAN   650.127.1634
# 37          128   Steven        Markle        SMARKLE    650.124.1434
# 44          135   Ki            Gee           KGEE       650.127.1734
# 36          127   James         Landry        JLANDRY    650.124.1334
# 49          140   Joshua        Patel         JPATEL     650.121.1834
# 40          131   James         Marlow        JAMRLOW    650.124.7234
# 28          119   Karen         Colmenares    KCOLMENA   515.127.4566
# 27          118   Guy           Himuro        GHIMURO    515.127.4565
# 0           198   Donald        OConnell      DOCONNEL   650.507.9833
# 1           199   Douglas       Grant         DGRANT     650.507.9844
# 35          126   Irene         Mikkilineni   IMIKKILI   650.124.1224
# 48          139   John          Seo           JSEO       650.121.2019
# 39          130   Mozhe         Atkinson      MATKINSO   650.124.6234
# 26          117   Sigal         Tobias        STOBIAS    515.127.4564
# 25          116   Shelli        Baida         SBAIDA     515.127.4563
# 43          134   Michael       Rogers        MROGERS    650.127.1834
# 24          115   Alexander     Khoo          AKHOO      515.127.4562
# 47          138   Stephen       Stiles        SSTILES    650.121.2034
# 34          125   Julia         Nayer         JNAYER     650.124.1214
# 38          129   Laura         Bissot        LBISSOT
# 42          133   Jason         Mallin        JMALLIN    650.127.1934
# 46          137   Renske        Ladwig        RLADWIG    650.121.1234
# 16          107   Diana         Lorentz       DLORENTZ
# 2           200   Jennifer      Whalen        JWHALEN    515.123.4444
# 15          106   Valli         Pataballa     VPATABAL   590.423.4560
# 14          105   David         Austin        DAUSTIN    590.423.4569
# 33          124   Kevin         Mourgos       KMOURGOS   650.123.5234
# 13          104   Bruce         Ernst         BERNST     590.423.4568
# 4           202   Pat           Fay           PFAY       603.123.6666
# 5           203   Susan         Mavris        SMAVRIS    515.123.7777
# 32          123   Shanta        Vollman       SVOLLMAN
# 22          113   Luis          Popp          LPOPP
# 20          111   Ismael        Sciarra       ISCIARRA   515.124.4369
# 21          112   Jose Manuel   Urman         JMURMAN    515.124.4469
# 31          122   Payam         Kaufling      PKAUFLIN   650.123.3234
# 29          120   Matthew       Weiss         MWEISS     650.123.1234
# 30          121   Adam          Fripp         AFRIPP     650.123.2234
# 19          110   John          Chen          JCHEN      515.124.4269
# 8           206   William       Gietz         WGIETZ     515.123.8181
# 18          109   Daniel        Faviet        DFAVIET    515.124.4169
# 12          103   Alexander     Hunold        AHUNOLD    590.423.4567
# 6           204   Hermann       Baer          HBAER      515.123.8888
# 23          114   Den           Raphaely      DRAPHEAL   515.127.4561
# 7           205   Shelley       Higgins       SHIGGINS
# 17          108   Nancy         Greenberg     NGREENBE   515.124.4569
# 3           201   Michael       Hartstein     MHARTSTE
# 11          102   Lex           De Haan       LDEHAAN    515.123.4569
# 10          101   Neena         Kochhar       NKOCHHAR   515.123.4568
# 9           100   Steven        King          SKING      515.123.4567
#
#      HIRE_DATE       JOB_ID  SALARY   COMMISSION_PCT  MANAGER_ID  \
# 41   10-Apr-07   ST_CLERK      2100                          121
# 45   6-Feb-08    ST_CLERK      2200                          122
# 37   8-Mar-08    ST_CLERK      2200                          120
# 44   12-Dec-07   ST_CLERK      2400                          122
# 36   14-Jan-07   ST_CLERK      2400                          120
# 49   6-Apr-06    ST_CLERK      2500                          123
# 40   16-Feb-05   ST_CLERK      2500                          121
# 28   10-Aug-07   PU_CLERK      2500                          114
# 27   15-Nov-06   PU_CLERK      2600                          114
# 0    21-Jun-07   SH_CLERK      2600                          124
# 1    13-Jan-08   SH_CLERK      2600                          124
# 35   28-Sep-06   ST_CLERK      2700                          120
# 48   12-Feb-06   ST_CLERK      2700                          123
# 39   30-Oct-05   ST_CLERK      2800                          121
# 26   24-Jul-05   PU_CLERK      2800                          114
# 25   24-Dec-05   PU_CLERK      2900                          114
# 43   26-Aug-06   ST_CLERK      2900                          122
# 24   18-May-03   PU_CLERK      3100                          114
# 47   26-Oct-05   ST_CLERK      3200                          123
# 34   16-Jul-05   ST_CLERK      3200                          120
# 38   20-Aug-05   ST_CLERK      3300                          121
# 42   14-Jun-04   ST_CLERK      3300                          122
# 46   14-Jul-03   ST_CLERK      3600                          123
# 16   7-Feb-07    IT_PROG       4200                          103
# 2    17-Sep-03   AD_ASST       4400                          101
# 15   5-Feb-06    IT_PROG       4800                          103
# 14   25-Jun-05   IT_PROG       4800                          103
# 33   16-Nov-07   ST_MAN        5800                          100
# 13   21-May-07   IT_PROG       6000                          103
# 4    17-Aug-05   MK_REP        6000                          201
# 5    7-Jun-02    HR_REP        6500                          101
# 32   10-Oct-05   ST_MAN        6500                          100
# 22   7-Dec-07    FI_ACCOUNT    6900                          108
# 20   30-Sep-05   FI_ACCOUNT    7700                          108
# 21   7-Mar-06    FI_ACCOUNT    7800                          108
# 31   1-May-03    ST_MAN        7900                          100
# 29   18-Jul-04   ST_MAN        8000                          100
# 30   10-Apr-05   ST_MAN        8200                          100
# 19   28-Sep-05   FI_ACCOUNT    8200                          108
# 8    7-Jun-02    AC_ACCOUNT    8300                          205
# 18   16-Aug-02   FI_ACCOUNT    9000                          108
# 12   3-Jan-06    IT_PROG       9000                          102
# 6    7-Jun-02    PR_REP       10000                          101
# 23   7-Dec-02    PU_MAN       11000                          100
# 7    7-Jun-02    AC_MGR       12008                          101
# 17   17-Aug-02   FI_MGR       12008                          101
# 3    17-Feb-04   MK_MAN       13000                          100
# 11   13-Jan-01   AD_VP        17000                          100
# 10   21-Sep-05   AD_VP        17000                          100
# 9    17-Jun-03   AD_PRES      24000                          100
#
#     DEPARTMENT_ID  ANNUAL_SALARY
# 41             50          25200
# 45             50          26400
# 37             50          26400
# 44             50          28800
# 36             50          28800
# 49             50          30000
# 40             50          30000
# 28             30          30000
# 27             30          31200
# 0              50          31200
# 1              50          31200
# 35             50          32400
# 48             50          32400
# 39             50          33600
# 26             30          33600
# 25             30          34800
# 43             50          34800
# 24             30          37200
# 47             50          38400
# 34             50          38400
# 38             50          39600
# 42             50          39600
# 46             50          43200
# 16             60          50400
# 2              10          52800
# 15             60          57600
# 14             60          57600
# 33             50          69600
# 13             60          72000
# 4              20          72000
# 5              40          78000
# 32             50          78000
# 22            100          82800
# 20            100          92400
# 21            100          93600
# 31             50          94800
# 29             50          96000
# 30             50          98400
# 19            100          98400
# 8             110          99600
# 18            100         108000
# 12             60         108000
# 6              70         120000
# 23             30         132000
# 7             110         144096
# 17            100         144096
# 3              20         156000
# 11             90         204000
# 10             90         204000
# 9              90         288000

# %% [markdown]
# # 13

# %%
data[data['JOB_ID'] == 'SH_CLERK']
# Out:
# Empty DataFrame
# Columns: [EMPLOYEE_ID, FIRST_NAME, LAST_NAME, EMAIL, PHONE_NUMBER, HIRE_DATE, JOB_ID, SALARY, COMMISSION_PCT, MANAGER_ID, DEPARTMENT_ID, ANNUAL_SALARY]
# Index: []

# %% [markdown]
# # 14

# %%
data['HIRE_DATE'] = pd.to_datetime(data['HIRE_DATE'], format='mixed')
data[data['HIRE_DATE'] > '2006-01-01']
# Out:
#     EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 0           198   Donald        OConnell      DOCONNEL   650.507.9833
# 1           199   Douglas       Grant         DGRANT     650.507.9844
# 12          103   Alexander     Hunold        AHUNOLD    590.423.4567
# 13          104   Bruce         Ernst         BERNST     590.423.4568
# 15          106   Valli         Pataballa     VPATABAL   590.423.4560
# 16          107   Diana         Lorentz       DLORENTZ
# 21          112   Jose Manuel   Urman         JMURMAN    515.124.4469
# 22          113   Luis          Popp          LPOPP
# 27          118   Guy           Himuro        GHIMURO    515.127.4565
# 28          119   Karen         Colmenares    KCOLMENA   515.127.4566
# 33          124   Kevin         Mourgos       KMOURGOS   650.123.5234
# 35          126   Irene         Mikkilineni   IMIKKILI   650.124.1224
# 36          127   James         Landry        JLANDRY    650.124.1334
# 37          128   Steven        Markle        SMARKLE    650.124.1434
# 41          132   TJ            Olson         TJOLSON    650.124.8234
# 43          134   Michael       Rogers        MROGERS    650.127.1834
# 44          135   Ki            Gee           KGEE       650.127.1734
# 45          136   Hazel         Philtanker    HPHILTAN   650.127.1634
# 48          139   John          Seo           JSEO       650.121.2019
# 49          140   Joshua        Patel         JPATEL     650.121.1834
#
#     HIRE_DATE       JOB_ID  SALARY   COMMISSION_PCT  MANAGER_ID  \
# 0  2007-06-21   SH_CLERK      2600                          124
# 1  2008-01-13   SH_CLERK      2600                          124
# 12 2006-01-03   IT_PROG       9000                          102
# 13 2007-05-21   IT_PROG       6000                          103
# 15 2006-02-05   IT_PROG       4800                          103
# 16 2007-02-07   IT_PROG       4200                          103
# 21 2006-03-07   FI_ACCOUNT    7800                          108
# 22 2007-12-07   FI_ACCOUNT    6900                          108
# 27 2006-11-15   PU_CLERK      2600                          114
# 28 2007-08-10   PU_CLERK      2500                          114
# 33 2007-11-16   ST_MAN        5800                          100
# 35 2006-09-28   ST_CLERK      2700                          120
# 36 2007-01-14   ST_CLERK      2400                          120
# 37 2008-03-08   ST_CLERK      2200                          120
# 41 2007-04-10   ST_CLERK      2100                          121
# 43 2006-08-26   ST_CLERK      2900                          122
# 44 2007-12-12   ST_CLERK      2400                          122
# 45 2008-02-06   ST_CLERK      2200                          122
# 48 2006-02-12   ST_CLERK      2700                          123
# 49 2006-04-06   ST_CLERK      2500                          123
#
#     DEPARTMENT_ID  ANNUAL_SALARY
# 0              50          31200
# 1              50          31200
# 12             60         108000
# 13             60          72000
# 15             60          57600
# 16             60          50400
# 21            100          93600
# 22            100          82800
# 27             30          31200
# 28             30          30000
# 33             50          69600
# 35             50          32400
# 36             50          28800
# 37             50          26400
# 41             50          25200
# 43             50          34800
# 44             50          28800
# 45             50          26400
# 48             50          32400
# 49             50          30000

# %% [markdown]
# # 15

# %%
data.groupby('DEPARTMENT_ID').size()
# Out:
# DEPARTMENT_ID
# 10      1
# 20      2
# 30      6
# 40      1
# 50     23
# 60      5
# 70      1
# 90      3
# 100     6
# 110     2
# dtype: int64

# %% [markdown]
# # 16

# %%
data['HIRE_YEAR'] = data['HIRE_DATE'].dt.year
data.groupby('HIRE_YEAR').size()
# Out:
# HIRE_YEAR
# 2001     1
# 2002     7
# 2003     5
# 2004     3
# 2005    14
# 2006     8
# 2007     9
# 2008     3
# dtype: int64

# %% [markdown]
# # 17

# %%
avrsal_by_department = data.groupby('DEPARTMENT_ID')['SALARY'].mean()
print(avrsal_by_department)
# Out:
# DEPARTMENT_ID
# 10      4400.000000
# 20      9500.000000
# 30      4150.000000
# 40      6500.000000
# 50      3721.739130
# 60      5760.000000
# 70     10000.000000
# 90     19333.333333
# 100     8601.333333
# 110    10154.000000
# Name: SALARY, dtype: float64

# %% [markdown]
# # 18

# %%
high_salary = avrsal_by_department[avrsal_by_department > 7000]
print(high_salary)
# Out:
# DEPARTMENT_ID
# 20      9500.000000
# 70     10000.000000
# 90     19333.333333
# 100     8601.333333
# 110    10154.000000
# Name: SALARY, dtype: float64

# %% [markdown]
# # 19

# %%
salary_by_department = data.groupby('DEPARTMENT_ID')['ANNUAL_SALARY'].sum()
print(salary_by_department)
# Out:
# DEPARTMENT_ID
# 10       52800
# 20      228000
# 30      298800
# 40       78000
# 50     1027200
# 60      345600
# 70      120000
# 90      696000
# 100     619296
# 110     243696
# Name: ANNUAL_SALARY, dtype: int64

# %% [markdown]
# # 20

# %%
data2 = data.sort_values('SALARY', ascending=False)
data2.head(5)
# or data2 = data.sort_values('SALARY', ascending=True).tail(5)
# Out:
#     EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 9           100   Steven        King          SKING      515.123.4567
# 11          102   Lex           De Haan       LDEHAAN    515.123.4569
# 10          101   Neena         Kochhar       NKOCHHAR   515.123.4568
# 3           201   Michael       Hartstein     MHARTSTE
# 17          108   Nancy         Greenberg     NGREENBE   515.124.4569
#
#     HIRE_DATE       JOB_ID  SALARY   COMMISSION_PCT  MANAGER_ID  \
# 9  2003-06-17   AD_PRES      24000                          100
# 11 2001-01-13   AD_VP        17000                          100
# 10 2005-09-21   AD_VP        17000                          100
# 3  2004-02-17   MK_MAN       13000                          100
# 17 2002-08-17   FI_MGR       12008                          101
#
#     DEPARTMENT_ID  ANNUAL_SALARY  HIRE_YEAR
# 9              90         288000       2003
# 11             90         204000       2001
# 10             90         204000       2005
# 3              20         156000       2004
# 17            100         144096       2002

# %% [markdown]
# # 21

# %%
data2.tail(5)
# Out:
#     EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 36          127   James         Landry        JLANDRY    650.124.1334
# 44          135   Ki            Gee           KGEE       650.127.1734
# 37          128   Steven        Markle        SMARKLE    650.124.1434
# 45          136   Hazel         Philtanker    HPHILTAN   650.127.1634
# 41          132   TJ            Olson         TJOLSON    650.124.8234
#
#     HIRE_DATE       JOB_ID  SALARY   COMMISSION_PCT  MANAGER_ID  \
# 36 2007-01-14   ST_CLERK      2400                          120
# 44 2007-12-12   ST_CLERK      2400                          122
# 37 2008-03-08   ST_CLERK      2200                          120
# 45 2008-02-06   ST_CLERK      2200                          122
# 41 2007-04-10   ST_CLERK      2100                          121
#
#     DEPARTMENT_ID  ANNUAL_SALARY  HIRE_YEAR
# 36             50          28800       2007
# 44             50          28800       2007
# 37             50          26400       2008
# 45             50          26400       2008
# 41             50          25200       2007

# %% [markdown]
# # 22

# %%
data.groupby('JOB_ID').size()
# Out:
# JOB_ID
# AC_ACCOUNT     1
# AC_MGR         1
# AD_ASST        1
# AD_PRES        1
# AD_VP          2
# FI_ACCOUNT     5
# FI_MGR         1
# HR_REP         1
# IT_PROG        5
# MK_MAN         1
# MK_REP         1
# PR_REP         1
# PU_CLERK       5
# PU_MAN         1
# SH_CLERK       2
# ST_CLERK      16
# ST_MAN         5
# dtype: int64

# %% [markdown]
# # 23

# %%
data['COMMISSION_PCT'] = 0.1
print(data[['FIRST_NAME', 'LAST_NAME', 'COMMISSION_PCT']])
# Out:
#       FIRST_NAME     LAST_NAME  COMMISSION_PCT
# 0    Donald        OConnell                0.1
# 1    Douglas       Grant                   0.1
# 2    Jennifer      Whalen                  0.1
# 3    Michael       Hartstein               0.1
# 4    Pat           Fay                     0.1
# 5    Susan         Mavris                  0.1
# 6    Hermann       Baer                    0.1
# 7    Shelley       Higgins                 0.1
# 8    William       Gietz                   0.1
# 9    Steven        King                    0.1
# 10   Neena         Kochhar                 0.1
# 11   Lex           De Haan                 0.1
# 12   Alexander     Hunold                  0.1
# 13   Bruce         Ernst                   0.1
# 14   David         Austin                  0.1
# 15   Valli         Pataballa               0.1
# 16   Diana         Lorentz                 0.1
# 17   Nancy         Greenberg               0.1
# 18   Daniel        Faviet                  0.1
# 19   John          Chen                    0.1
# 20   Ismael        Sciarra                 0.1
# 21   Jose Manuel   Urman                   0.1
# 22   Luis          Popp                    0.1
# 23   Den           Raphaely                0.1
# 24   Alexander     Khoo                    0.1
# 25   Shelli        Baida                   0.1
# 26   Sigal         Tobias                  0.1
# 27   Guy           Himuro                  0.1
# 28   Karen         Colmenares              0.1
# 29   Matthew       Weiss                   0.1
# 30   Adam          Fripp                   0.1
# 31   Payam         Kaufling                0.1
# 32   Shanta        Vollman                 0.1
# 33   Kevin         Mourgos                 0.1
# 34   Julia         Nayer                   0.1
# 35   Irene         Mikkilineni             0.1
# 36   James         Landry                  0.1
# 37   Steven        Markle                  0.1
# 38   Laura         Bissot                  0.1
# 39   Mozhe         Atkinson                0.1
# 40   James         Marlow                  0.1
# 41   TJ            Olson                   0.1
# 42   Jason         Mallin                  0.1
# 43   Michael       Rogers                  0.1
# 44   Ki            Gee                     0.1
# 45   Hazel         Philtanker              0.1
# 46   Renske        Ladwig                  0.1
# 47   Stephen       Stiles                  0.1
# 48   John          Seo                     0.1
# 49   Joshua        Patel                   0.1

# %% [markdown]
# # 24

# %%
data['NEW_SALARY'] = data['SALARY'] * (1 + data['COMMISSION_PCT'])
print(data[['FIRST_NAME', 'LAST_NAME', 'SALARY', 'COMMISSION_PCT', 'NEW_SALARY']])
# Out:
#       FIRST_NAME     LAST_NAME  SALARY  COMMISSION_PCT  NEW_SALARY
# 0    Donald        OConnell       2600             0.1      2860.0
# 1    Douglas       Grant          2600             0.1      2860.0
# 2    Jennifer      Whalen         4400             0.1      4840.0
# 3    Michael       Hartstein     13000             0.1     14300.0
# 4    Pat           Fay            6000             0.1      6600.0
# 5    Susan         Mavris         6500             0.1      7150.0
# 6    Hermann       Baer          10000             0.1     11000.0
# 7    Shelley       Higgins       12008             0.1     13208.8
# 8    William       Gietz          8300             0.1      9130.0
# 9    Steven        King          24000             0.1     26400.0
# 10   Neena         Kochhar       17000             0.1     18700.0
# 11   Lex           De Haan       17000             0.1     18700.0
# 12   Alexander     Hunold         9000             0.1      9900.0
# 13   Bruce         Ernst          6000             0.1      6600.0
# 14   David         Austin         4800             0.1      5280.0
# 15   Valli         Pataballa      4800             0.1      5280.0
# 16   Diana         Lorentz        4200             0.1      4620.0
# 17   Nancy         Greenberg     12008             0.1     13208.8
# 18   Daniel        Faviet         9000             0.1      9900.0
# 19   John          Chen           8200             0.1      9020.0
# 20   Ismael        Sciarra        7700             0.1      8470.0
# 21   Jose Manuel   Urman          7800             0.1      8580.0
# 22   Luis          Popp           6900             0.1      7590.0
# 23   Den           Raphaely      11000             0.1     12100.0
# 24   Alexander     Khoo           3100             0.1      3410.0
# 25   Shelli        Baida          2900             0.1      3190.0
# 26   Sigal         Tobias         2800             0.1      3080.0
# 27   Guy           Himuro         2600             0.1      2860.0
# 28   Karen         Colmenares     2500             0.1      2750.0
# 29   Matthew       Weiss          8000             0.1      8800.0
# 30   Adam          Fripp          8200             0.1      9020.0
# 31   Payam         Kaufling       7900             0.1      8690.0
# 32   Shanta        Vollman        6500             0.1      7150.0
# 33   Kevin         Mourgos        5800             0.1      6380.0
# 34   Julia         Nayer          3200             0.1      3520.0
# 35   Irene         Mikkilineni    2700             0.1      2970.0
# 36   James         Landry         2400             0.1      2640.0
# 37   Steven        Markle         2200             0.1      2420.0
# 38   Laura         Bissot         3300             0.1      3630.0
# 39   Mozhe         Atkinson       2800             0.1      3080.0
# 40   James         Marlow         2500             0.1      2750.0
# 41   TJ            Olson          2100             0.1      2310.0
# 42   Jason         Mallin         3300             0.1      3630.0
# 43   Michael       Rogers         2900             0.1      3190.0
# 44   Ki            Gee            2400             0.1      2640.0
# 45   Hazel         Philtanker     2200             0.1      2420.0
# 46   Renske        Ladwig         3600             0.1      3960.0
# 47   Stephen       Stiles         3200             0.1      3520.0
# 48   John          Seo            2700             0.1      2970.0
# 49   Joshua        Patel          2500             0.1      2750.0

# %% [markdown]
# # 25

# %%
data[data['MANAGER_ID'] == 124]
# Out:
#    EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 0          198   Donald        OConnell      DOCONNEL   650.507.9833
# 1          199   Douglas       Grant         DGRANT     650.507.9844
#
#    HIRE_DATE       JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  \
# 0 2007-06-21   SH_CLERK      2600             0.1         124             50
# 1 2008-01-13   SH_CLERK      2600             0.1         124             50
#
#    ANNUAL_SALARY  HIRE_YEAR  NEW_SALARY
# 0          31200       2007      2860.0
# 1          31200       2008      2860.0

# %% [markdown]
# # 26

# %%
data['NEW_ANNUAL_SALARY'] = data['ANNUAL_SALARY'] * (1 + data['COMMISSION_PCT'])
data.groupby('DEPARTMENT_ID')['NEW_ANNUAL_SALARY'].sum()
# Out:
# DEPARTMENT_ID
# 10       58080.0
# 20      250800.0
# 30      328680.0
# 40       85800.0
# 50     1129920.0
# 60      380160.0
# 70      132000.0
# 90      765600.0
# 100     681225.6
# 110     268065.6
# Name: NEW_ANNUAL_SALARY, dtype: float64

# %% [markdown]
# # 27

# %%
# print(data.columns)
# data["PHONE_NUMBER"].astype(str)
data["PHONE_NUMBER"].str.startswith('650', na=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: PHONE_NUMBER, dtype: bool

# %% [markdown]
# # 28

# %%
data["YEARS_OF_SERVICE"] = 2025 - data['HIRE_DATE'].dt.year
data["YEARS_OF_SERVICE"]
# Out:
# 0     18
# 1     17
# 2     22
# 3     21
# 4     20
# 5     23
# 6     23
# 7     23
# 8     23
# 9     22
# 10    20
# 11    24
# 12    19
# 13    18
# 14    20
# 15    19
# 16    18
# 17    23
# 18    23
# 19    20
# 20    20
# 21    19
# 22    18
# 23    23
# 24    22
# 25    20
# 26    20
# 27    19
# 28    18
# 29    21
# 30    20
# 31    22
# 32    20
# 33    18
# 34    20
# 35    19
# 36    18
# 37    17
# 38    20
# 39    20
# 40    20
# 41    18
# 42    21
# 43    19
# 44    18
# 45    17
# 46    22
# 47    20
# 48    19
# 49    19
# Name: YEARS_OF_SERVICE, dtype: int32

# %% [markdown]
# # 29

# %%
data[data["ANNUAL_SALARY"] > data.groupby('DEPARTMENT_ID')['ANNUAL_SALARY'].transform('mean')]
# Out:
#     EMPLOYEE_ID    FIRST_NAME     LAST_NAME      EMAIL   PHONE_NUMBER  \
# 3           201   Michael       Hartstein     MHARTSTE
# 7           205   Shelley       Higgins       SHIGGINS
# 9           100   Steven        King          SKING      515.123.4567
# 12          103   Alexander     Hunold        AHUNOLD    590.423.4567
# 13          104   Bruce         Ernst         BERNST     590.423.4568
# 17          108   Nancy         Greenberg     NGREENBE   515.124.4569
# 18          109   Daniel        Faviet        DFAVIET    515.124.4169
# 23          114   Den           Raphaely      DRAPHEAL   515.127.4561
# 29          120   Matthew       Weiss         MWEISS     650.123.1234
# 30          121   Adam          Fripp         AFRIPP     650.123.2234
# 31          122   Payam         Kaufling      PKAUFLIN   650.123.3234
# 32          123   Shanta        Vollman       SVOLLMAN
# 33          124   Kevin         Mourgos       KMOURGOS   650.123.5234
#
#     HIRE_DATE       JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  \
# 3  2004-02-17   MK_MAN       13000             0.1         100             20
# 7  2002-06-07   AC_MGR       12008             0.1         101            110
# 9  2003-06-17   AD_PRES      24000             0.1         100             90
# 12 2006-01-03   IT_PROG       9000             0.1         102             60
# 13 2007-05-21   IT_PROG       6000             0.1         103             60
# 17 2002-08-17   FI_MGR       12008             0.1         101            100
# 18 2002-08-16   FI_ACCOUNT    9000             0.1         108            100
# 23 2002-12-07   PU_MAN       11000             0.1         100             30
# 29 2004-07-18   ST_MAN        8000             0.1         100             50
# 30 2005-04-10   ST_MAN        8200             0.1         100             50
# 31 2003-05-01   ST_MAN        7900             0.1         100             50
# 32 2005-10-10   ST_MAN        6500             0.1         100             50
# 33 2007-11-16   ST_MAN        5800             0.1         100             50
#
#     ANNUAL_SALARY  HIRE_YEAR  NEW_SALARY  NEW_ANNUAL_SALARY  YEARS_OF_SERVICE
# 3          156000       2004     14300.0           171600.0                21
# 7          144096       2002     13208.8           158505.6                23
# 9          288000       2003     26400.0           316800.0                22
# 12         108000       2006      9900.0           118800.0                19
# 13          72000       2007      6600.0            79200.0                18
# 17         144096       2002     13208.8           158505.6                23
# 18         108000       2002      9900.0           118800.0                23
# 23         132000       2002     12100.0           145200.0                23
# 29          96000       2004      8800.0           105600.0                21
# 30          98400       2005      9020.0           108240.0                20
# 31          94800       2003      8690.0           104280.0                22
# 32          78000       2005      7150.0            85800.0                20
# 33          69600       2007      6380.0            76560.0                18

# %% [markdown]
# # 30

# %%
data.groupby('DEPARTMENT_ID')['SALARY'].max()
# Out:
# DEPARTMENT_ID
# 10      4400
# 20     13000
# 30     11000
# 40      6500
# 50      8200
# 60      9000
# 70     10000
# 90     24000
# 100    12008
# 110    12008
# Name: SALARY, dtype: int64

# %% [markdown]
# # 31

# %%
# data['PHONE_NUMBER']

data[data['PHONE_NUMBER'].isnull()]
# Out:
# Empty DataFrame
# Columns: [EMPLOYEE_ID, FIRST_NAME, LAST_NAME, EMAIL, PHONE_NUMBER, HIRE_DATE, JOB_ID, SALARY, COMMISSION_PCT, MANAGER_ID, DEPARTMENT_ID, ANNUAL_SALARY, HIRE_YEAR, NEW_SALARY, NEW_ANNUAL_SALARY, YEARS_OF_SERVICE]
# Index: []
